# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import datetime as dt
from pandas.plotting import table
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
data=pd.read_csv('employee.csv')
data.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
plt.figure(figsize=[12,12])
plt.hist(data['Age'],bins=20,color='g')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age ')
# Out:
# Text(0.5, 1.0, 'Distribution of Age ')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['DailyRate'],bins=20,color='grey')
plt.xlabel('DailyRate')
plt.ylabel('Frequency')
plt.title('Distribution of DailyRate ')
# Out:
# Text(0.5, 1.0, 'Distribution of DailyRate ')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['DistanceFromHome'],bins=25,color='cyan')
plt.xlabel('DistanceFromHome')
plt.ylabel('Frequency')
plt.title('Distribution of Distance From Home')
# Out:
# Text(0.5, 1.0, 'Distribution of Distance From Home')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['EmployeeNumber'],bins=25,color='blue')
plt.xlabel('EmployeeNumber')
plt.ylabel('Frequency')
plt.title('Distribution of Employee Number')
# Out:
# Text(0.5, 1.0, 'Distribution of Employee Number')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['HourlyRate'],bins=25,color='skyblue')
plt.xlabel('HourlyRate')
plt.ylabel('Frequency')
plt.title('Distribution of Hourly Rate')
# Out:
# Text(0.5, 1.0, 'Distribution of Hourly Rate')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['MonthlyIncome'],bins=25,color='red')
plt.xlabel('MonthlyIncome')
plt.ylabel('Frequency')
plt.title('Distribution of MonthlyIncome')
# Out:
# Text(0.5, 1.0, 'Distribution of MonthlyIncome')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['PercentSalaryHike'],bins=10,color='pink')
plt.xlabel('PercentSalaryHike')
plt.ylabel('Frequency')
plt.title('Distribution of Percent Salary Hike')
# Out:
# Text(0.5, 1.0, 'Distribution of Percent Salary Hike')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['TotalWorkingYears'],bins=25,color='orange')
plt.xlabel('TotalWorkingYears')
plt.ylabel('Frequency')
plt.title('Distribution of Total Working Years')
# Out:
# Text(0.5, 1.0, 'Distribution of Total Working Years')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['YearsAtCompany'],bins=25,color='magenta')
plt.xlabel('YearsAtCompany')
plt.ylabel('Frequency')
plt.title('Distribution of Years At Company')
# Out:
# Text(0.5, 1.0, 'Distribution of Years At Company')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['YearsInCurrentRole'],bins=25,color='lightblue')
plt.xlabel('YearsInCurrentRole')
plt.ylabel('Frequency')
plt.title('Distribution of Years In Current Role')
# Out:
# Text(0.5, 1.0, 'Distribution of Years In Current Role')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['YearsSinceLastPromotion'],bins=25,color='black')
plt.xlabel('YearsSinceLastPromotion')
plt.ylabel('Frequency')
plt.title('Distribution of Years Since Last Promotion')
# Out:
# Text(0.5, 1.0, 'Distribution of Years Since Last Promotion')

# %%
plt.figure(figsize=[12,12])
plt.hist(data['YearsWithCurrManager'],bins=25,color='lightblue')
plt.xlabel('YearsWithCurrManager')
plt.ylabel('Frequency')
plt.title('Distribution of Years With Current Manager')
# Out:
# Text(0.5, 1.0, 'Distribution of Years With Current Manager')

# %%
def bar_plot(variable):
    #get feature
    var = data[variable]
    #count number of categorical variable(value/sample)
    varValue = var.value_counts()
   
    #visualize
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable, varValue))

# %%
category1 = ["Attrition"]
for c in category1:
    bar_plot(c)
# Out:
# Attrition:
#  No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
category1 = ["Education"]
for c in category1:
    bar_plot(c)
# Out:
# Education:
#  3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
category1 = ["EnvironmentSatisfaction"]
for c in category1:
    bar_plot(c)
# Out:
# EnvironmentSatisfaction:
#  3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
category1 = ["JobInvolvement","JobLevel","JobSatisfaction","Over18","OverTime","PerformanceRating","StockOptionLevel","TrainingTimesLastYear","WorkLifeBalance"]
for c in category1:
    bar_plot(c)
# Out:
# JobInvolvement:
#  3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64
# JobLevel:
#  1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64
# JobSatisfaction:
#  4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64
# Over18:
#  Y    1470
# Name: Over18, dtype: int64
# OverTime:
#  No     1054
# Yes     416
# Name: OverTime, dtype: int64
# PerformanceRating:
#  3    1244
# 4     226
# Name: PerformanceRating, dtype: int64
# StockOptionLevel:
#  0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64
# TrainingTimesLastYear:
#  2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64
# WorkLifeBalance:
#  3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
category1 = ["BusinessTravel","Department","EducationField","Gender","JobRole","MaritalStatus"]
for c in category1:
    bar_plot(c)
# Out:
# BusinessTravel:
#  Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# Department:
#  Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# EducationField:
#  Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# Gender:
#  Male      882
# Female    588
# Name: Gender, dtype: int64
# JobRole:
#  Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# MaritalStatus:
#  Married     673
# Single      470
# Divorced    327
# ...

# %%
data['AnnIncome']=data['MonthlyIncome']*1000
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'AnnIncome'],
#       dtype='object')

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="JobRole", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="MonthlyIncome", hue="JobRole", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="BusinessTravel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="Department", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="Education", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="EducationField", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="EnvironmentSatisfaction", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="JobInvolvement", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="JobLevel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="JobRole", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="JobSatisfaction", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="OverTime", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="PerformanceRating", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="StockOptionLevel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Gender", y="AnnIncome", hue="TrainingTimesLastYear", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="BusinessTravel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="Education", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="EducationField", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="EnvironmentSatisfaction", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="Gender", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="JobInvolvement", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="JobLevel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="JobRole", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="JobSatisfaction", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="MaritalStatus", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="OverTime", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="PerformanceRating", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="RelationshipSatisfaction", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="StockOptionLevel", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="TrainingTimesLastYear", data=data, kind="box")
plt.show()

# %%
sns.factorplot(x="Department", y="AnnIncome", hue="WorkLifeBalance", data=data, kind="box")
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
x = data.loc[:, ['Age','MonthlyRate']].values

# %%
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method', fontsize = 20)
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)


plt.rcParams['figure.figsize'] = (15, 8)
plt.style.use('fivethirtyeight')

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'pink', label = 'miser')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'yellow', label = 'general')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'cyan', label = 'target')
#plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'magenta', label = 'spendthrift')
#plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'careful')
#plt.scatter(x[y_means == 5, 0], x[y_means == 5, 1], s = 100, c = 'gray', label = 'careful')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.style.use('fivethirtyeight')
plt.title('K Means Clustering', fontsize = 20)
plt.xlabel('JobSatisfaction')
plt.ylabel('MonthlyRate')
plt.legend()
plt.grid()
plt.show()

# %%
# for interactive visualizations
plt.style.use('fivethirtyeight')
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected = True)
import plotly.figure_factory as ff

x = data[['Age', 'MonthlyRate', 'PerformanceRating']].values
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
km.fit(x)
labels = km.labels_
centroids = km.cluster_centers_
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data['labels'] =  labels
trace1 = go.Scatter3d(
    x= data['Age'],
    y= data['MonthlyRate'],
    z= data['PerformanceRating'],
    mode='markers',
     marker=dict(
        color = data['labels'], 
        size= 10,
        line=dict(
            color= data['labels'],
            width= 12
        ),
        opacity=0.8
     )
)
df = [trace1]

layout = go.Layout(
    title = 'Character vs Gender vs Alive or not',
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0  
    ),
    scene = dict(
            xaxis = dict(title  = 'Age'),
            yaxis = dict(title  = 'MonthlyRate'),
            zaxis = dict(title  = 'PerformanceRating')
        )
)

fig = go.Figure(data = df, layout = layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="4dc64586-ca96-4a05-a35e-b4f3c493f0b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4dc64586-ca96-4a05-a35e-b4f3c493f0b6")) {
#                     Plotly.newPlot(
#                         '4dc64586-ca96-4a05-a35e-b4f3c493f0b6',
# ...

# %%
x = data[['Age', 'AnnIncome', 'JobSatisfaction']].values
km = KMeans(n_clusters = 7, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
km.fit(x)
labels = km.labels_
centroids = km.cluster_centers_

# %%
data['labels'] =  labels
trace1 = go.Scatter3d(
    x= data['Age'],
    y= data['AnnIncome'],
    z= data['JobSatisfaction'],
    mode='markers',
     marker=dict(
        color = data['labels'], 
        size= 10,
        line=dict(
            color= data['labels'],
            width= 12
        ),
        opacity=0.8
     )
)
df = [trace1]

layout = go.Layout(
    title = 'Character vs Gender vs Alive or not',
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0  
    ),
    scene = dict(
            xaxis = dict(title  = 'Age'),
            yaxis = dict(title  = 'AnnIncome'),
            zaxis = dict(title  = 'JobSatisfaction')
        )
)

fig = go.Figure(data = df, layout = layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="c064137b-779e-4f94-9364-7c8557e1c711" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c064137b-779e-4f94-9364-7c8557e1c711")) {
#                     Plotly.newPlot(
#                         'c064137b-779e-4f94-9364-7c8557e1c711',
# ...

# %%
x = data[['Age', 'AnnIncome', 'Education']].values
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
km.fit(x)
labels = km.labels_
centroids = km.cluster_centers_

# %%
data['labels'] =  labels
trace1 = go.Scatter3d(
    x= data['Age'],
    y= data['AnnIncome'],
    z= data['Education'],
    mode='markers',
     marker=dict(
        color = data['labels'], 
        size= 10,
        line=dict(
            color= data['labels'],
            width= 12
        ),
        opacity=0.8
     )
)
df = [trace1]

layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0  
    ),
    scene = dict(
            xaxis = dict(title  = 'Age'),
            yaxis = dict(title  = 'AnnIncome'),
            zaxis = dict(title  = 'Education')
        )
)

fig = go.Figure(data = df, layout = layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="53453dfb-2882-4f50-ac71-5eb077c0653e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("53453dfb-2882-4f50-ac71-5eb077c0653e")) {
#                     Plotly.newPlot(
#                         '53453dfb-2882-4f50-ac71-5eb077c0653e',
# ...
